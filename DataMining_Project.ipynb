# %%
#Wine Project

# %%
import pandas as pd

# %%
# Reading the data from file
wine_df = pd.read_csv('wine.csv')
wine_df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    6497.000000       6497.000000  6497.000000     6497.000000
# mean        7.214586          0.339632     0.318649        5.443508
# std         1.296304          0.164620     0.145325        4.758042
# min         3.799620          0.079992     0.000000        0.600030
# 25%         6.399360          0.229977     0.250013        1.800090
# 50%         6.999300          0.289971     0.310016        3.000150
# 75%         7.699230          0.399960     0.390020        8.100405
# max        15.898410          1.579842     1.660083       65.803290
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  6497.000000          6491.000000           6497.000000  6494.000000
# mean      0.056031            30.535805            115.738941     0.994596
# std       0.035032            17.756039             56.518925     0.002998
# ...

# %%
wine_df.shape
# Out:
# (6497, 13)

# %%
wine_df.isna().mean()
# Out:
# fixed acidity           0.000000
# volatile acidity        0.000000
# citric acid             0.000000
# residual sugar          0.000000
# chlorides               0.000000
# free sulfur dioxide     0.000924
# total sulfur dioxide    0.000000
# density                 0.000462
# pH                      0.000000
# sulphates               0.002309
# alcohol                 0.001539
# Type                    0.000000
# quality                 0.000000
# dtype: float64

# %%
#wine_df = wine_df.loc[:,wine_df.isna().mean()<0.50]
wine_df.head(20)
# Out:
#     fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0         7.39926          0.964904     0.000000        2.200110   0.087996
# 1        12.29877          0.389961     0.630032        2.300115   0.090995
# 2         6.39936          0.269973     0.490025        7.300365   0.045998
# 3         7.39926          0.189981     0.300015       12.800640   0.052997
# 4         6.19938          0.339966     0.300015       11.100555   0.046998
# 5         4.99950          0.609939     0.120006        1.300065   0.009000
# 6         7.29927          0.409959     0.290015        1.800090   0.031998
# 7         6.59934          0.229977     0.180009        8.500425   0.043998
# 8         5.99940          0.359964     0.160008        6.300315   0.035998
# 9         6.59934          0.209979     0.290015        5.350268   0.028999
# 10       10.59894          0.279972     0.390020       15.500775   0.068997
# ...

# %%
wine_df.Type.value_counts()
# Out:
# Red      4898
# White    1599
# Name: Type, dtype: int64
